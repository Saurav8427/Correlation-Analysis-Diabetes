# %%
#overall
import pandas as pd
import seaborn as sns
import itertools
from matplotlib import *
import matplotlib.pyplot as plt

#df = pd.read_csv('graph_all.csv')
Feature = ['HOMA-R'
,'AVAT CELL SIZE (Abdominal Visceral)'
,'Visceral Fat (in cm Sq.) MRI'
,'Subcutaneous fat (in cm Sq.) MRI'
,'Liver % fat signal intensity MRI'
,'ASAT CELL SIZE (Abdominal Subcutaneous )'
,'MR VAT/MRSAT'
,'VAT AREA/VAT CELL SIZE'
,'SAT AREA/SAT CELL SIZE'
,'WAIST'
,'BMI'
,'MRVAT/MRSAT SIZE CORRECTED'
,'VATSIZE/SATSIZE'
,'GROUP']*6
Percentage = [
              
             2.193645357024273,2.2965063226054876,7.934738093066171,3.745255974323896,2.379044656361734,
              1.7898046629036997,15.935083536183667,8.399580067831701,5.477814373576221,7.447575313476233,
              11.688278305565614,23.110507301350957,7.413502395871093,0.18866363985925472,
              
             2.145531,10.27712,5.774711,0.431591,0.137125,2.852715,19.28997,22.470089,0.317716,5.77338,
              5.13113,23.156328,2.093125,0.149469,
              
             4.867768399202451,10.4560302220463,7.918827130985704,2.192057043079509,1.236449202524299,
              5.603666164235068,14.041916879949012,15.051663149626574,1.881275559604136,7.917938415831503,
              7.475632853379441,15.257364678110418,4.808541898537736,1.2908684028878528]

Algorithm = ['randomforest', 'univariate','pearson']
Algorithm = list(itertools.chain(*(itertools.repeat(i, 14) for i in Algorithm)))

df = pd.DataFrame(list(zip(Percentage, Algorithm, Feature)), columns =['Percentage', 'Algorithm', 'Feature']) 
pd.set_option("display.max_rows", None, "display.max_columns", None)

plt.subplots(figsize=(50, 30))
plt.xlabel('Feature', fontsize=50)
plt.ylabel('Percentage', fontsize=50)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
sns.set_theme(style="whitegrid")
ax = sns.lineplot(data=df, x="Feature", y="Percentage", hue="Algorithm", style="Algorithm", markers=True,linewidth = 5.5, markersize=14)
ax.tick_params(labelsize=40)
ax.axes.set_title("Overall",fontsize=60)
ax.legend(fontsize = 40)

# %%
#group 1
import pandas as pd
import seaborn as sns
import itertools
from matplotlib import *
import matplotlib.pyplot as plt

#df = pd.read_csv('graph_all.csv')
Feature = ['HOMA-R'
,'AVAT CELL SIZE (Abdominal Visceral)'
,'Visceral Fat (in cm Sq.) MRI'
,'Subcutaneous fat (in cm Sq.) MRI'
,'Liver % fat signal intensity MRI'
,'ASAT CELL SIZE (Abdominal Subcutaneous )'
,'MR VAT/MRSAT'
,'VAT AREA/VAT CELL SIZE'
,'SAT AREA/SAT CELL SIZE'
,'WAIST'
,'BMI'
,'MRVAT/MRSAT SIZE CORRECTED'
,'VATSIZE/SATSIZE'
,'GROUP']*6

Percentage = [
             21.156181200526564,13.093602577974185,6.5390985750733766,3.408190139234437,5.185254235610135,
              4.100594453426893,6.295242708879384,4.403371398667995,10.680225805712931,2.513006619082835,
              9.534645153208334,6.138991212890772,6.351376425730377,0.6002194939817839,
             34.776541,14.311418,0.999472,3.06888,0.013584,0.032669,4.121767,1.159547,2.891002,0.727962,
              11.044931,0.006604,2.009063,24.83656,
             18.90738825435963,13.333880261507685,3.4856596255884797,7.183481506016038,0.8194220741192905,
              0.6891643963383282,7.794647083482601,4.497236962882537,5.808490484281336,3.2397942140948293,
              11.913706335027868,0.2920321571353514,5.341886282512647,16.693210362653378]

Algorithm = ['randomforest', 'univariate', 'pearson']
Algorithm = list(itertools.chain(*(itertools.repeat(i, 14) for i in Algorithm)))

df = pd.DataFrame(list(zip(Percentage, Algorithm, Feature)), columns =['Percentage', 'Algorithm', 'Feature']) 
pd.set_option("display.max_rows", None, "display.max_columns", None)
# print(df)

plt.subplots(figsize=(50, 30))
plt.xlabel('Feature', fontsize=50)
plt.ylabel('Percentage', fontsize=50)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
sns.set_theme(style="whitegrid")
ax = sns.lineplot(data=df, x="Feature", y="Percentage", hue="Algorithm", style="Algorithm", markers=True,linewidth = 5.5, markersize=14)
ax.tick_params(labelsize=40)
ax.axes.set_title("Group 1 [0, 1)",fontsize=60)
ax.legend(fontsize = 40)

# %%
#group 2
import pandas as pd
import seaborn as sns
import itertools
from matplotlib import *
import matplotlib.pyplot as plt

#df = pd.read_csv('graph_all.csv')
Feature = ['HOMA-R'
,'AVAT CELL SIZE (Abdominal Visceral)'
,'Visceral Fat (in cm Sq.) MRI'
,'Subcutaneous fat (in cm Sq.) MRI'
,'Liver % fat signal intensity MRI'
,'ASAT CELL SIZE (Abdominal Subcutaneous )'
,'MR VAT/MRSAT'
,'VAT AREA/VAT CELL SIZE'
,'SAT AREA/SAT CELL SIZE'
,'WAIST'
,'BMI'
,'MRVAT/MRSAT SIZE CORRECTED'
,'VATSIZE/SATSIZE'
,'GROUP']*6

Percentage = [
             3.0364236451358977,2.7755482611990225,1.8238551219530534,2.340756106769008,6.384601010847132,
              2.5308231216271895,3.9620441894126626,7.426564698552387,54.9490349929515,1.171200616290793,
              0.5941600243610656,2.137325016143137,10.756066858491305,0.11159633626584764,
             6.590996,24.317762,3.46779,6.100214,1.743899,3.514826,0.362797,8.284144,32.876259,
              7.1e-05,3.629519,0.135022,8.973779,0.00292,
             9.032005639409713,15.618890258638926,6.690658389732043,8.717486507354362,4.801912131552519,
              6.733702580399524,2.2118324383254935,10.014677195579292,17.382838002515403,0.03104279935621232,
              6.837297266468367,1.3515581660913112,10.377135807210909,0.19896281736590718]

Algorithm = ['randomforest', 'univariate', 'pearson']
Algorithm = list(itertools.chain(*(itertools.repeat(i, 14) for i in Algorithm)))

df = pd.DataFrame(list(zip(Percentage, Algorithm, Feature)), columns =['Percentage', 'Algorithm', 'Feature']) 
pd.set_option("display.max_rows", None, "display.max_columns", None)
# print(df)

plt.subplots(figsize=(50, 30))
plt.xlabel('Feature', fontsize=50)
plt.ylabel('Percentage', fontsize=50)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
sns.set_theme(style="whitegrid")
ax = sns.lineplot(data=df, x="Feature", y="Percentage", hue="Algorithm", style="Algorithm", markers=True,linewidth = 5.5, markersize=14)
ax.tick_params(labelsize=40)
ax.axes.set_title("Group 2 [1, 2)",fontsize=60)
ax.legend(fontsize = 40)

# %%
#group 3
import pandas as pd
import seaborn as sns
import itertools
from matplotlib import *
import matplotlib.pyplot as plt

#df = pd.read_csv('graph_all.csv')
Feature = ['HOMA-R'
,'AVAT CELL SIZE (Abdominal Visceral)'
,'Visceral Fat (in cm Sq.) MRI'
,'Subcutaneous fat (in cm Sq.) MRI'
,'Liver % fat signal intensity MRI'
,'ASAT CELL SIZE (Abdominal Subcutaneous )'
,'MR VAT/MRSAT'
,'VAT AREA/VAT CELL SIZE'
,'SAT AREA/SAT CELL SIZE'
,'WAIST'
,'BMI'
,'MRVAT/MRSAT SIZE CORRECTED'
,'VATSIZE/SATSIZE'
,'GROUP']*6

Percentage = [
             1.5391030273419881,1.501370457879136,22.78031679946797,2.188456033207004,4.033727706428807,
              7.160353073403093,6.464275642152762,21.657429835369904,4.353376817709279,6.035290602391634,
              2.5439246004277534,15.9897642278989,2.491996826501076,1.2606143498206925,
             10.103372,0.008211,41.592947,5.609308,5.226363,0.006607,3.262925,16.921282,6.309636,
              4.543473,0.006255,0.504228,0.805925,5.099468,
             12.005031065731309,0.3810663017592126,17.453089811614344,8.29301339577876,8.802034336009468,
              0.3418427570846418,5.3161067646980715,13.480962187089768,9.516301735828245,8.5169152105237,
              0.33260602562136315,2.8513061044673256,3.7400395624499843,8.969684741343793]

Algorithm = ['randomforest', 'univariate', 'pearson']
Algorithm = list(itertools.chain(*(itertools.repeat(i, 14) for i in Algorithm)))

df = pd.DataFrame(list(zip(Percentage, Algorithm, Feature)), columns =['Percentage', 'Algorithm', 'Feature']) 
pd.set_option("display.max_rows", None, "display.max_columns", None)
# print(df)

plt.subplots(figsize=(50, 30))
plt.xlabel('Feature', fontsize=50)
plt.ylabel('Percentage', fontsize=50)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
sns.set_theme(style="whitegrid")
ax = sns.lineplot(data=df, x="Feature", y="Percentage", hue="Algorithm", style="Algorithm", markers=True,linewidth = 5.5, markersize=14)
ax.tick_params(labelsize=40)
ax.axes.set_title("Group 3 [2, 7)]",fontsize=60)
ax.legend(fontsize = 40)

# %%
#group 4
import pandas as pd
import seaborn as sns
import itertools
from matplotlib import *
import matplotlib.pyplot as plt

#df = pd.read_csv('graph_all.csv')
Feature = ['HOMA-R'
,'AVAT CELL SIZE (Abdominal Visceral)'
,'Visceral Fat (in cm Sq.) MRI'
,'Subcutaneous fat (in cm Sq.) MRI'
,'Liver % fat signal intensity MRI'
,'ASAT CELL SIZE (Abdominal Subcutaneous )'
,'MR VAT/MRSAT'
,'VAT AREA/VAT CELL SIZE'
,'SAT AREA/SAT CELL SIZE'
,'WAIST'
,'BMI'
,'MRVAT/MRSAT SIZE CORRECTED'
,'VATSIZE/SATSIZE'
,'GROUP']*6

Percentage = [
             3.138187732134464,3.118848850751151,37.22295682423153,2.4009852468962074,7.920791630039123,
              8.825417164092169,7.88879332223474,4.89943202329849,3.619428859318659,3.2699786988636528,
              7.258759455316118,1.6250252600707529,8.53731859598746,0.27407633676547966,
             1.71109,7.71916,43.915279,0.09421,9.675838,0.159656,2.03272,3.155371,0.681346,3.436792,
              1.446107,2.937796,22.977052,0.057584,
             5.051328299049426,10.257955967618905,19.86337843492527,1.2005422876487868,11.327434328609696,
              1.5620458933182082,5.491852008366545,6.78337914835926,3.213489721594721,7.064237389326797,
              4.653404017886582,6.556245125422885,16.035830157424492,0.9388772204484128]

Algorithm = ['randomforest', 'univariate', 'pearson']
Algorithm = list(itertools.chain(*(itertools.repeat(i, 14) for i in Algorithm)))

df = pd.DataFrame(list(zip(Percentage, Algorithm, Feature)), columns =['Percentage', 'Algorithm', 'Feature']) 
pd.set_option("display.max_rows", None, "display.max_columns", None)
# print(df)

plt.subplots(figsize=(50, 30))
plt.xlabel('Feature', fontsize=50)
plt.ylabel('Percentage', fontsize=50)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
sns.set_theme(style="whitegrid")
ax = sns.lineplot(data=df, x="Feature", y="Percentage", hue="Algorithm", style="Algorithm", markers=True,linewidth = 5.5, markersize=14)
ax.tick_params(labelsize=40)
ax.axes.set_title("Group 4 [7, 30)",fontsize=60)
ax.legend(fontsize = 40)

# %%
#group 4
import pandas as pd
import seaborn as sns
import itertools
from matplotlib import *
import matplotlib.pyplot as plt

#df = pd.read_csv('graph_all.csv')
Feature = ['HOMA-R'
,'AVAT CELL SIZE (Abdominal Visceral)'
,'Visceral Fat (in cm Sq.) MRI'
,'Subcutaneous fat (in cm Sq.) MRI'
,'Liver % fat signal intensity MRI'
,'ASAT CELL SIZE (Abdominal Subcutaneous )'
,'MR VAT/MRSAT'
,'VAT AREA/VAT CELL SIZE'
,'SAT AREA/SAT CELL SIZE'
,'WAIST'
,'BMI'
,'MRVAT/MRSAT SIZE CORRECTED'
,'VATSIZE/SATSIZE'
,'GROUP']*6

Percentage = [
             3.1490185828789805,5.352275776161547,20.687660659049204,5.589340903677122,4.007422693490226,
              3.737772556484384,3.443135784983886,21.71558966967227,7.638707758175961,9.702096872022409,
              4.4507005999851055,6.310715788672715,3.5892165489674452,0.6263458057787515,
             3.053888,4.273259,24.634725,0.061842,0.146611,6.330808,4.558694,33.438879,4.915,8.578786,0.575927,
              8.980927,0.432135,0.018518,
             7.416333572562885,8.519751785692328,14.649920535268587,1.143350235740423,1.7561171698205202,
              9.905526056786467,8.741694783892193,15.512549424991537,9.003361241158695,11.015922103396255,
              3.438231007186833,5.280408653590198,2.9903915679559803,0.6264418619570866]

Algorithm = ['randomforest', 'univariate', 'pearson']
Algorithm = list(itertools.chain(*(itertools.repeat(i, 14) for i in Algorithm)))

df = pd.DataFrame(list(zip(Percentage, Algorithm, Feature)), columns =['Percentage', 'Algorithm', 'Feature']) 
pd.set_option("display.max_rows", None, "display.max_columns", None)
# print(df)

plt.subplots(figsize=(50, 30))
plt.xlabel('Feature', fontsize=50)
plt.ylabel('Percentage', fontsize=50)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
sns.set_theme(style="whitegrid")
ax = sns.lineplot(data=df, x="Feature", y="Percentage", hue="Algorithm", style="Algorithm", markers=True,linewidth = 5.5, markersize=14)
ax.tick_params(labelsize=40)
ax.axes.set_title("Group 5 [30, inf)",fontsize=60)
ax.legend(fontsize = 40)
